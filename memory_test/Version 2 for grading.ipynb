# %%
# %run Memory_Test.py
# Out:
# <h2>You got 9/29 correct.
# </h2>
#                            <h2>You used 68.4 seconds to complete the test. Very good job!
# </h2>
#                            <h2>End of the game! Thanks for your participation.</h2>
